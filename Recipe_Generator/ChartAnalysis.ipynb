# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##Charts for the MLM task

# %%
TrainingLosses = [0.118, 0.1029, 0.1018, 0.098, 0.096, 0.096,   0.085, 0.090, 0.087, 0.088, 0.089, 0.089,      0.090, 0.086, 0.088, 0.085, 0.086, 0.084,        0.080, 0.081, 0.079, 0.078, 0.081]
ValidationLosses = [0.090, 0.081, 0.079, 0.076, 0.0786, 0.078,  0.078, 0.076, 0.0747, 0.0748, 0.072, 0.0738,   0.072, 0.0718, 0.0714, 0.0717, 0.0702, 0.0708,   0.077, 0.076, 0.077, 0.0760, 0.0769 ]

# %%
xi = list(range(1, len(TrainingLosses)+1))
plt.plot(xi, TrainingLosses, label='Training Loss')
plt.plot(xi, ValidationLosses, label='Validation Loss')
plt.xlabel('6 Steps = 1 Epoch')
plt.ylabel('Losses')
plt.xticks(xi)
plt.legend()
plt.locator_params(nbins=12)
plt.show()

# %% [markdown]
# ##**ROUGE Scores**
# The metric of ROUGE scores at the end of 3 epochs of MLM
# *   **rouge1**: 0.9259
# *   **rouge2**: 0.8627
# *   **rougeL**: 0.9258

# %%
perplexity = [34, 37, 35]
bleuScores = [0.646, 0.652, 0.658]

# %%
xi = [1, 2, 3]
plt.subplot(2, 2, 2)
plt.plot(xi, perplexity, marker='o')
plt.xlabel('Epochs')
plt.xticks(xi)
plt.tight_layout()
plt.title("Perplexity")
plt.show()

plt.subplot(2, 2, 2)
plt.plot(xi, bleuScores, marker='o')
plt.xlabel('Epochs')
plt.xticks(xi)
plt.tight_layout()
plt.title("BLEU Score")
plt.show()

# %% [markdown]
# ##Charts for the recipe generation task

# %%
TrainingLosses = [1.309, 1.117, 1.089, 1.066, 1.043,    1.059, 0.999, 0.993, 0.976, 0.969,    0.980, 0.967, 0.956, 0.962, 0.955,   0.956, 0.935, 0.947, 0.937, 0.929,   0.931, 0.949, 0.915, 0.917, 0.929]
ValidationLosses = [1.054, 1.018, 1.001, 0.991, 0.989,  0.972, 0.946, 0.930, 0.919, 0.909,    0.902, 0.898, 0.895, 0.893, 0.892,   0.887, 0.883, 0.880, 0.879, 0.877,   0.875, 0.871, 0.868, 0.867, 0.865]

# %%
xi = list(range(1, len(TrainingLosses)+1))
plt.plot(xi, TrainingLosses, label='Training Loss')
plt.plot(xi, ValidationLosses, label='Validation Loss')
plt.xlabel('5 Steps = 1 Epoch')
plt.ylabel('Losses')
plt.xticks(xi)
plt.legend()
plt.locator_params(nbins=10)
plt.show()

# %%
similarity = [0.558, 0.612, 0.622, 0.622, 0.634]

# %%
plt.subplot(2, 2, 2)
plt.plot(similarity, marker='o')
plt.xlabel('Epochs')
xi = list(range(len(similarity)))
plt.xticks(xi)
plt.tight_layout()
plt.ylim((0.55, 0.65))
plt.title("Similarity")
plt.show()

# %% [markdown]
# Despite the similarity, for this task the ROUGE score is not the most appropriate metric

# %%
rouge1 = [25.45, 31.45, 32.88, 32.67, 33.11]
rouge2 = [8.14, 10.14, 9.86, 10.14, 10.24]
rougeL = [19.38, 22.38, 22.87, 22.88, 23.19]

# %%
xi = [1, 2, 3, 4, 5]
plt.plot(xi, rouge1, marker='o', label='Rouge1')
plt.plot(xi, rouge2, marker='o', label='Rouge2')
plt.plot(xi, rougeL, marker='o', label='RougeL')
plt.xlabel('Epochs')
plt.xticks(xi)
plt.legend()
plt.show()
